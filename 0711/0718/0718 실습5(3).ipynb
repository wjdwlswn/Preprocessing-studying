# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
from bs4 import BeautifulSoup
with open('full_book_list.html', encoding='utf-8')as f:
    soup= BeautifulSoup(f,'html.parser')
for a in soup.find_all('a'):
    print(a.get('href'),a.text)
# Out:
# #gnb 메뉴 바로가기
# #top_search 검색 및 카테고리 바로가기
# #main_top_box 프로모션 바로가기
# #main_book_area 책 바로가기
# #main_network_area 네트워크 바로가기
# https://www.hanbit.co.kr/index.html HOME
# https://www.hanbit.co.kr/media/ 한빛미디어
# https://www.hanbit.co.kr/academy/ 한빛아카데미
# https://www.hanbit.co.kr/biz/ 한빛비즈
# https://www.hanbit.co.kr/life/ 한빛라이프
# https://www.hanbit.co.kr/edu/ 한빛에듀
# https://www.hanbit.co.kr/realtime/ 리얼타임
# https://www.hanbit.co.kr/textbook/ 한빛정보교과서
# https://www.hanbit.co.kr/rent/ 한빛대관서비스
# https://www.hanbit.co.kr/member/login.html 로그인
# https://www.hanbit.co.kr/member/member_agree.html 회원가입
# https://www.hanbit.co.kr/myhanbit/myhanbit.html 마이한빛
# https://www.hanbit.co.kr/myhanbit/cart.html 장바구니
# https://www.hanbit.co.kr/publisher/foreignrights.html?lang=e ENGLISH
# https://www.hanbit.co.kr/index.html 한빛출판네트워크
# https://www.hanbit.co.kr/brand/brand_submain.html BRAND
# https://www.hanbit.co.kr/channel/channel_submain.html Channel.H
# https://www.hanbit.co.kr/store/store_submain.html STORE
# https://www.hanbit.co.kr/support/help_info.html SUPPORT
# https://www.hanbit.co.kr/event/current/current_event_list.html EVENT
# https://www.hanbit.co.kr/publisher/foreignrights.html?lang=e RIGHTS
# javascript:; SEARCH
# None
#                   {{ keyword.number }} {{ keyword.bookName }}
#
# None
#                   {{ keyword.number }} {{ keyword.bookName }}
#
# None
# None
#
#
# None
# None
# javascript:; 닫기
# /event/current/current_event_view.html?hbe_idx=172
# /store/books/look.php?p_code=B6361762764
#
# 한빛미디어
# 아이패드 드로잉 with 프로크리에이트
# 더 쉽게, 더 재미있게 아이패드 드로잉을 시작하자!
#
#
#
#
#
#
# /store/books/look.php?p_code=B5825921855
#
# 한빛미디어
# 사례 분석으로 배우는 데이터 시각화
# 기초가 탄탄한 데이터 시각화 입문서
#
#
#
#
#
#
# https://www.hanbit.co.kr/devletter/
# javascript:;
# javascript:;
# /publisher/write.html?lang=k
#
# 기획/원고 모집
#
# /academy/professor/
#
# 교수전용
#
# /rent/
#
# 대관서비스
#
# /support/supplement_list.html
#
# 부록/예제소스
#
# https://support.hanbit.co.kr/hc/ko/categories/200229407-%EC%9E%90%EC%A3%BC-%EB%AC%BB%EB%8A%94-%EC%A7%88%EB%AC%B8-FAQ-
#
# 자주묻는질문
#
# /publisher/foreignrights.html?lang=e
#
# FOREIGN RIGHTS
#
# javascript:main_book_display(1,1); 새로나온책
# javascript:main_book_display(2,1); 베스트셀러
# /store/books/look.php?p_code=B8661740335
# javascript:;
# /store/books/look.php?p_code=B6084607806
# javascript:;
# /store/books/look.php?p_code=B1382037871
# javascript:;
# /store/books/look.php?p_code=B4162156367
# /store/books/look.php?p_code=B5156679966
# /store/books/look.php?p_code=B6189263297
# /store/books/look.php?p_code=B8806843023
# javascript:;
# /store/books/look.php?p_code=B4813114979
# javascript:;
# /store/books/look.php?p_code=B2859439220
# /store/books/look.php?p_code=B1996635146
# javascript:;
# /store/books/look.php?p_code=B4354575770
# javascript:;
# /store/books/look.php?p_code=B9063949643
# /store/books/look.php?p_code=B7798657798
# javascript:;
# /store/books/look.php?p_code=B5171715268
# /store/books/look.php?p_code=B7400451696
# javascript:;
# javascript:;
# /store/books/new_book_list.html 더보기
# javascript:main_book_display(1,1); 새로나온책
# javascript:main_book_display(2,1); 베스트셀러
# /store/books/look.php?p_code=B1207366943
# javascript:;
# /store/books/look.php?p_code=B2002963743
# javascript:;
# /store/books/look.php?p_code=B1854329839
# javascript:;
# /store/books/look.php?p_code=B7422209817
# /store/books/look.php?p_code=B8945183661
# javascript:;
# /store/books/look.php?p_code=B3346434043
# javascript:;
# /store/books/look.php?p_code=B4622884510
# /store/books/look.php?p_code=B6318137900
# /store/books/look.php?p_code=B1710834745
# /store/books/look.php?p_code=B7748014142
# javascript:;
# /store/books/look.php?p_code=B1765707537
# javascript:;
# /store/books/look.php?p_code=E1054933296
# javascript:;
# /store/books/look.php?p_code=E9745937947
# javascript:;
# /store/books/look.php?p_code=B4035028569
# javascript:;
# /store/books/look.php?p_code=B6952616555
# javascript:;
# javascript:;
# javascript:;
# /store/books/bestseller_list.html 더보기
# https://blog.hanbit.co.kr
# https://www.instagram.com/hanbit.pub/
# https://www.youtube.com/%ED%95%9C%EB%B9%9BTV
# https://m.post.naver.com/hanbitstory
# https://www.facebook.com/hanbitmedia
# /channel/channel_submain.html
# https://blog.hanbit.co.kr/284
#
# 2022 서울국제도서전을 다녀오다 - 코엑스! 2년만인가!
#
# /channel/category/category_view.html?cms_code=CMS2118567228
#
# 개발자에 의한, 개발자를 위한...“데브렐이란 무엇인가?”
#
# /channel/category/category_view.html?cms_code=CMS7108503140
#
# 어느 구글러의 경험담: 내 코드를 숨기고 싶어요
#
# https://blog.hanbit.co.kr/282
#
# 지나치게 재미있는 아카데미 워크숍♥
#
# https://youtu.be/Xtih85QeSB8
#
# 미라클모닝 시작은 정말 6시일까?_해답드림(미라클모닝 도서 담당자들)
#
# /channel/category/category_view.html?cms_code=CMS7895414616
#
# 캐글 대회에서 가장 많은 우승을...XGBoost란?
#
# /channel/category/category_view.html?cms_code=CMS9733780399
#
# 파이썬과 엑셀 비교, python 업무 자동화 사례 알아보기
#
# /channel/category/category_view.html?cms_code=CMS7678783507
#
# 창시자가 말하는 엘릭서 언어의 탄생, “실용적으로 접근한 함수형 프로그래밍”
#
# /support/notice_list.html 공지사항
# /support/notice_list.html 더보기
# /support/notice_view.html?hnb_idx=318
# [채용공고] IT활용서 분야 도서 기획편집자(경력) 모집(서류전형 : 22/5/30 ~ 22/6/15)
#
# /support/notice_view.html?hnb_idx=317
# BIZSIREN 서버 교체 작업으로 본인인증서비스 중단 안내(22년 5월 26일 03:00~06:00)
#
# /support/notice_view.html?hnb_idx=316
# [채용공고] 한빛라이프 여행 분야 도서 기획/편집자 모집
#
# javascript:;
# /myhanbit/cart.html 장바구니이동
# javascript:; 쇼핑계속
# https://www.hanbit.co.kr/publisher/index.html 회사소개
# https://www.hanbit.co.kr/publisher/index.html KOR
# https://www.hanbit.co.kr/publisher/index.html?lang=e ENG
# https://www.hanbit.co.kr/publisher/contact.html?lang=k 약도
# https://www.hanbit.co.kr/publisher/write.html 기획 및 원고 모집
# https://www.hanbit.co.kr/publisher/career.html 채용
# mailto:jobs@hanbit.co.kr jobs@hanbit.co.kr
# https://www.hanbit.co.kr/publisher/foreignrights.html FOREIGN RIGHTS
# https://www.hanbit.co.kr/member/use_agreement.html 이용약관
# https://www.hanbit.co.kr/member/privacy_policy.html 개인정보처리방침
# https://www.hanbit.co.kr/sitemap/sitemap.html 사이트맵
# /devletter/ 데브레터 보러가기
# https://www.facebook.com/hanbitmedia 페이스북
# https://www.youtube.com/한빛TV 유튜브
# http://blog.hanbit.co.kr/ 블로그
# https://m.post.naver.com/hanbitstory 네이버포스트
# http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2208105665 [확인]
# https://www.hanbit.co.kr/support/supplement_list.html 자료실

# %%
for a in soup.find_all('a'):
    print(a.get('href'),a.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 for a in soup.find_all('a'):
#       2     print(a.get('href'),a.text)
#
# NameError: name 'soup' is not defined
